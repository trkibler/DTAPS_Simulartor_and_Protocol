# %%
import json
import Simulator.Config as Config
import os

# %%
config_file_path = "./config.json"

print(os.path.exists(config_file_path))

with open(config_file_path, "r") as conf_file:
    try:
        data = json.load(conf_file)
        for i in data:
            print(i)
            print(data[i])
    except json.JSONDecodeError:
        print("Error: Config file JSON decoding failed. Please ensure that file is in proper JSON format")
# Out:
# True
# duration
# 3600.0
# network_size
# 10
# disruption_rate
# 0.8
# disruption_pattern
# UNIFORM_RANDOM
# connectivity_window_min
# 1.0
# connectivity_window_max
# 30.0
# message_generation_rate
# 0.1
# message_size_range
# [100, 10000]
# bandwidth_range
# [1000, 1000000]
# dtaps_mode
# BALANCED
# network_topology
# RANDOM_GRAPH

# %%
Config.SimulationConfig.check_config("./config.json")

print(Config.SimulationConfig.duration)
print(Config.SimulationConfig.network_size)
print(Config.SimulationConfig.disruption_rate)
print(Config.SimulationConfig.disruption_pattern.name)
print(Config.SimulationConfig.connectivity_window_min)
print(Config.SimulationConfig.connectivity_window_max)
print(Config.SimulationConfig.message_generation_rate)
print(Config.SimulationConfig.message_size_range)
print(Config.SimulationConfig.bandwidth_range)
print(Config.SimulationConfig.dtaps_mode.name)
print(Config.SimulationConfig.network_topology.name)
# Out:
# 3600.0
# 10
# 0.8
# UNIFORM_RANDOM
# 1.0
# 30.0
# 0.1
# (100, 10000)
# (1000, 1000000)
# BALANCED
# RANDOM_GRAPH

# %%
Config.SimulationConfig.check_config("./alt_config.json")

print(Config.SimulationConfig.duration)
print(Config.SimulationConfig.network_size)
print(Config.SimulationConfig.disruption_rate)
print(Config.SimulationConfig.disruption_pattern.name)
print(Config.SimulationConfig.connectivity_window_min)
print(Config.SimulationConfig.connectivity_window_max)
print(Config.SimulationConfig.message_generation_rate)
print(Config.SimulationConfig.message_size_range)
print(Config.SimulationConfig.bandwidth_range)
print(Config.SimulationConfig.dtaps_mode.name)
print(Config.SimulationConfig.network_topology.name)
# Out:
# 5555.0
# 77
# 0.99
# REALISTIC_MOBILE
# 5.0
# 50.0
# 0.25
# (30, 3000)
# (600, 6000)
# HIGH_RELIABILITY
# SMALL_WORLD
